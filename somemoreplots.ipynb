# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
int_count=[30813,30041, 26582, 26122, 25483, 24454, 23813, 23001, 22145, 21136, 20465,
      19370, 18329, 16698, 15475, 14559, 13930, 13062, 12371, 12029, 11335, 10855,
      10093, 9883, 9496, 9007, 8139, 7964, 7530, 7259, 7098, 7106, 7053, 6845, 6659,
      6820, 6625, 6116, 5411, 4591, 3193, 1830, 994, 939, 218, 138, 81, 58, 42, 38, 53]
window_count=[9400, 9336, 9365, 8134, 8626,  8900, 9021, 9038, 8876, 8838, 8607,8146, 7242,
         6508,5839, 5441, 5026, 4811, 4781, 4403, 4077, 3752, 3368, 3046, 2601, 2234, 1710,
         1461,1467, 1833, 2663, 3624, 5162, 6107, 6272,6584, 6525, 6344, 5817, 4895, 3493, 
         2071, 1197, 509, 215, 90, 29, 28, 19, 5, 22]

# %%
for i in range(len(window_count)):
    try:
        print("{:.2f}".format(time[i]),window_count[i])
    except:
        print(time[i],window_count[i])
# Out:
# 0.00 9400
# 0.10 9336
# 0.20 9365
# 0.30 8134
# 0.40 8626
# 0.50 8900
# 0.60 9021
# 0.70 9038
# 0.80 8876
# 0.90 8838
# 1.00 8607
# 1.10 8146
# 1.20 7242
# 1.30 6508
# 1.40 5839
# 1.50 5441
# 1.60 5026
# 1.70 4811
# 1.80 4781
# 1.90 4403
# 2.00 4077
# 2.10 3752
# 2.20 3368
# 2.30 3046
# 2.40 2601
# 2.50 2234
# 2.60 1710
# 2.70 1461
# 2.80 1467
# 2.90 1833
# 3.00 2663
# 3.10 3624
# 3.20 5162
# 3.30 6107
# 3.40 6272
# 3.50 6584
# 3.60 6525
# 3.70 6344
# 3.80 5817
# 3.90 4895
# 4.00 3493
# 4.10 2071
# 4.20 1197
# 4.30 509
# 4.40 215
# 4.50 90
# 4.60 29
# 4.70 28
# 4.80 19
# 4.90 5
# 5.00 22

# %%
time = np.arange(0,5.1,0.1)

# %%
time

# %%
plt.figure(dpi=300)

plt.style.use('ggplot')

plt.plot(time,int_count,c="orange",zorder=5)
plt.scatter(time,int_count,s=10,zorder=10,label="Integral Counts")

plt.annotate(text="Drops here",xy=(4,7000))
plt.legend(loc ='upper right',facecolor="white")
plt.xlabel("Volts")
plt.ylabel("Counts")

plt.title("Integral Single Channel Analyzer")

plt.show()

plt.figure(dpi=300)

plt.plot(time,window_count,c="orange",zorder=5)

plt.scatter(time,window_count,s=10,zorder=10,label="Differential Counts")


plt.annotate(text="Peak here",xy=(3.5,7000))
plt.legend(loc ='upper right',facecolor="white")
plt.xlabel("Volts")
plt.ylabel("Counts")

plt.title("Differential Single Channel Analyzer")
plt.show()
